# %% [markdown]
# <a href="https://colab.research.google.com/github/ajaywabale245-eng/student-performance-data-analysis/blob/main/Student_Performance_Data_Analysis_%F0%9F%93%8A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, Data Analysis!")
# Out:
# Hello, Data Analysis!

# %%
import pandas as pd

# %%
data = {
    "Name": ["Ajay", "Rahul", "Priya"],
    "Marks": [85, 78, 92]
}

df = pd.DataFrame(data)

df
# Out:
#     Name  Marks
# 0   Ajay     85
# 1  Rahul     78
# 2  Priya     92

# %%
df = pd.DataFrame(data)

# %%
df.to_csv("student_data.csv", index=False)

# %%
print("CSV file created successfully!")
# Out:
# CSV file created successfully!

# %%
df = pd.read_csv("student_data.csv")

df
# Out:
#     Name  Marks
# 0   Ajay     85
# 1  Rahul     78
# 2  Priya     92

# %%
df.head()
# Out:
#     Name  Marks
# 0   Ajay     85
# 1  Rahul     78
# 2  Priya     92

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    3 non-null      object
#  1   Marks   3 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 180.0+ bytes

# %%
df.shape
# Out:
# (3, 2)

# %%
df.describe()
# Out:
#        Marks
# count    3.0
# mean    85.0
# std      7.0
# min     78.0
# 25%     81.5
# 50%     85.0
# 75%     88.5
# max     92.0

# %%
df["Marks"].mean()
# Out:
# np.float64(85.0)

# %%
df["Marks"].max()
# Out:
# 92

# %%
df["Marks"].min()
# Out:
# 78

# %%
df.sort_values("Marks")
# Out:
#     Name  Marks
# 1  Rahul     78
# 0   Ajay     85
# 2  Priya     92

# %%
df.sort_values("Marks", ascending=False)
# Out:
#     Name  Marks
# 2  Priya     92
# 0   Ajay     85
# 1  Rahul     78

# %%
df[df["Marks"] > 80]
# Out:
#     Name  Marks
# 0   Ajay     85
# 2  Priya     92

# %%
df[df["Marks"] >= 80]
# Out:
#     Name  Marks
# 0   Ajay     85
# 2  Priya     92

# %%
import pandas as pd

# %%
import pandas as pd

# %%
data = {
    "Name": ["Ajay", "Rahul", "Priya"],
    "Marks": [85, 78, 92]
}

# %%
df = pd.DataFrame(data)

# %%
df.to_csv("student_data.csv", index=False)

# %%
print("CSV file created successfully!")

df
# Out:
# CSV file created successfully!
#     Name  Marks
# 0   Ajay     85
# 1  Rahul     78
# 2  Priya     92

# %%
df = pd.read_csv("student_data.csv")
df
# Out:
#     Name  Marks
# 0   Ajay     85
# 1  Rahul     78
# 2  Priya     92

# %%
df["Department"] = ["AIDS", "CSE", "AIDS"]
df
# Out:
#     Name  Marks Department
# 0   Ajay     85       AIDS
# 1  Rahul     78        CSE
# 2  Priya     92       AIDS

# %%
df.groupby("Department")["Marks"].mean()
# Out:
# Department
# AIDS    88.5
# CSE     78.0
# Name: Marks, dtype: float64

# %%
df.isnull().sum()
# Out:
# Name          0
# Marks         0
# Department    0
# dtype: int64

# %%
df["Marks"] = df["Marks"].fillna(df["Marks"].mean())

df
# Out:
#     Name  Marks Department
# 0   Ajay     85       AIDS
# 1  Rahul     78        CSE
# 2  Priya     92       AIDS

# %%
df.isnull().sum()
# Out:
# Name          0
# Marks         0
# Department    0
# dtype: int64

# %%
print("Average Marks:", df["Marks"].mean())
print("Highest Marks:", df["Marks"].max())
print("Lowest Marks:", df["Marks"].min())
# Out:
# Average Marks: 85.0
# Highest Marks: 92
# Lowest Marks: 78

# %%
import matplotlib.pyplot as plt

# %%
plt.bar(df["Name"], df["Marks"])
plt.xlabel("Student Name")
plt.ylabel("Marks")
plt.title("Student Marks Analysis")
plt.show()

# %% [markdown]
# Conclusion
# In this project, I analyzed student performance data using Python, Pandas, and NumPy. I learned how to import CSV data, explore and clean the dataset, handle missing values, calculate average, maximum and minimum marks, and visualize the data using a bar chart.
